# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanievelez/21_days_to_data/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data-district-crime_vic_age.csv')
df.head(5)
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD        BORO_NM          CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0   831526991           67       BROOKLYN  2018-03-31T00:00:00Z     23:30:00
# 1   496736340          120  STATEN ISLAND  2018-03-31T00:00:00Z     23:20:00
# 2   399593692          105         QUEENS  2018-03-31T00:00:00Z     23:15:00
# 3   282376455          110         QUEENS  2018-03-31T00:00:00Z     23:10:00
# 4   201598299           78       BROOKLYN  2018-03-31T00:00:00Z     23:10:00
#
#            CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD         HADEVELOPT  \
# 0  2018-03-31T00:00:00Z     23:37:00        COMPLETED                NaN
# 1  2018-03-31T00:00:00Z     23:30:00        COMPLETED   RICHMOND TERRACE
# 2  2018-03-31T00:00:00Z     23:20:00        COMPLETED                NaN
# 3  2018-03-31T00:00:00Z     23:20:00        COMPLETED                NaN
# 4  2018-03-31T00:00:00Z     23:19:00        COMPLETED  572 WARREN STREET
#
# ...

# %%
df[df['BORO_NM']=='BROOKLYN']['CMPLNT_FR_TM']
# Out:
#         CMPLNT_NUM  ADDR_PCT_CD   BORO_NM          CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0        831526991           67  BROOKLYN  2018-03-31T00:00:00Z     23:30:00
# 4        201598299           78  BROOKLYN  2018-03-31T00:00:00Z     23:10:00
# 5        513742569           88  BROOKLYN  2018-03-31T00:00:00Z     22:58:00
# 18       401613518           68  BROOKLYN  2018-03-31T00:00:00Z     22:15:00
# 21       149230249           75  BROOKLYN  2018-03-31T00:00:00Z     22:15:00
# ...            ...          ...       ...                   ...          ...
# 109528   455382765           71  BROOKLYN  2017-09-01T00:00:00Z     18:00:00
# 109530   632120479           60  BROOKLYN  2017-05-03T00:00:00Z     12:00:00
# 109531   756498047           90  BROOKLYN  2017-01-08T00:00:00Z     00:01:00
# 109533   867281571           79  BROOKLYN  2017-01-01T00:00:00Z     21:05:00
# 109537   271487603           79  BROOKLYN  2016-09-27T00:00:00Z     00:01:00
#
# ...

# %%
df[['DATE', 'TIME']] = df['CMPLNT_TO_DT'].str.split('T', expand=True)
df['DATE'] =pd.to_datetime(df['DATE'], format='%Y-%m-%d')

# %%
df['month']=df['DATE'].dt.month #converts this data frame into date time months
df.head(5)
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD        BORO_NM          CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0   831526991           67       BROOKLYN  2018-03-31T00:00:00Z     23:30:00
# 1   496736340          120  STATEN ISLAND  2018-03-31T00:00:00Z     23:20:00
# 2   399593692          105         QUEENS  2018-03-31T00:00:00Z     23:15:00
# 3   282376455          110         QUEENS  2018-03-31T00:00:00Z     23:10:00
# 4   201598299           78       BROOKLYN  2018-03-31T00:00:00Z     23:10:00
#
#            CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD         HADEVELOPT  \
# 0  2018-03-31T00:00:00Z     23:37:00        COMPLETED                NaN
# 1  2018-03-31T00:00:00Z     23:30:00        COMPLETED   RICHMOND TERRACE
# 2  2018-03-31T00:00:00Z     23:20:00        COMPLETED                NaN
# 3  2018-03-31T00:00:00Z     23:20:00        COMPLETED                NaN
# 4  2018-03-31T00:00:00Z     23:19:00        COMPLETED  572 WARREN STREET
#
# ...

# %%
df['weekday'] = df['DATE'].dt.day_name()
df['weekday']
# Out:
# 0         Saturday
# 1         Saturday
# 2         Saturday
# 3         Saturday
# 4         Saturday
#             ...
# 109538    Thursday
# 109539      Monday
# 109540      Monday
# 109541      Monday
# 109542      Monday
# Name: weekday, Length: 109543, dtype: object
